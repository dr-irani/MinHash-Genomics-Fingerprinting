# %%
import pandas as pd
import altair as alt
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
figsize = (16, 10)

# %%
df = pd.read_csv('synthdata_estimated_editdistance.txt', sep='\t')

# %%
df.head()
# Out:
#    len_x  len_y        TJ        J1        J2        J3        J4  trueED  \
# 0   8001   8001  0.519361  0.312500  0.468750  0.007812  0.526180   197.0
# 1   8001   8001  0.392935  0.218750  0.367188  0.007812  0.395434   296.0
# 2   8001   8001  0.289671  0.195312  0.265625  0.007812  0.288916   396.0
# 3   8001   8001  0.229123  0.156250  0.234375  0.007812  0.229659   489.0
# 4   8001   8001  0.181825  0.093750  0.164062  0.007812  0.185542   584.0
#
#    TED[0]       TED[1]     ...          ED1[2]  ED2[0]       ED2[1]  \
# 0     0.0  5612.987085     ...      261.937500     0.0  4898.571429
# 1     0.0  3912.564993     ...      320.552885     0.0  3598.535885
# 2     0.0  2710.192833     ...      336.643382     0.0  2450.756757
# 3     0.0  2070.405233     ...      364.910473     0.0  2124.159292
# 4     0.0  1600.265131     ...      414.337500     0.0  1429.965957
#
#        ED2[2]  ED3[0]     ED3[1]      ED3[2]  ED4[0]       ED4[1]      ED4[2]
# 0  180.873670     0.0  62.752941  492.309593     0.0  5712.994053  155.250258
# 1  231.457500     0.0  62.752941  492.309593     0.0  3943.585386  216.649797
# 2  290.159722     0.0  62.752941  492.309593     0.0  2701.931381  275.880303
# 3  310.165348     0.0  62.752941  492.309593     0.0  2075.877075  313.272486
# 4  359.105285     0.0  62.752941  492.309593     0.0  1636.324266  343.539050
#
# [5 rows x 23 columns]

# %%
df.loc[:, ['TED[0]', 'TED[1]', 'TED[2]']].plot(figsize=figsize)

# %%
df.loc[:, ['TED[2]', 'ED1[2]', 'ED2[2]', 'ED3[2]', 'ED4[2]']].plot(figsize=figsize)

# %%
# eds = df.loc[:, ['ED1[2]', 'ED2[2]', 'ED3[2]', 'ED4[2]']]

fig, ax = plt.subplots(1,1,figsize=figsize)
plt.title('Edit Distance Approximation')
ax.plot(df.loc[:, 'TED[2]'],  df.loc[:, ['ED1[2]', 'ED2[2]', 'ED3[2]', 'ED4[2]']], linestyle='None', marker='.', markersize=15.0)
ax.set(xlabel='True Edit Distance', ylabel='Estimated Edit Distance')
ax.legend(df.loc[:, ['ED1[2]', 'ED2[2]', 'ED3[2]', 'ED4[2]']])

# lims = [
#     np.min([ax.get_xlim(), ax.get_ylim()]),  # min of both axes
#     np.max([ax.get_xlim(), ax.get_ylim()]),  # max of both axes
# ]

# # now plot both limits against eachother
# ax.plot(lims, lims, 'k-', alpha=0.75, zorder=0)
# ax.set_aspect('equal')
# ax.set_xlim(lims)
# ax.set_ylim(lims)

ax.plot([0,1],[0,1], transform=ax.transAxes)

# %%
df.loc[:, ['ED1[2]', 'ED2[2]', 'ED3[2]', 'ED4[2]']]
# Out:
#         ED1[2]      ED2[2]      ED3[2]      ED4[2]
